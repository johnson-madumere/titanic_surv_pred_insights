# %%
from titanic_surv.dataset import load_data

data = load_data()
data.head()
# Out:
# 2026-02-10 11:06:02.240 | INFO     | titanic_surv.config:<module>:11 - PROJ_ROOT path is: D:\py\Titanic\titanic_surv_pred_insights
# 2026-02-10 11:06:02.791 | INFO     | titanic_surv.dataset:load_data:13 - Starting dataset processing
# 2026-02-10 11:06:02.791 | INFO     | titanic_surv.dataset:load_data:19 - Loading data from D:\py\Titanic\titanic_surv_pred_insights\data\raw\titanic.csv
#    Passengerid   Age     Fare  Sex  sibsp  zero  zero.1  zero.2  zero.3  \
# 0            1  22.0   7.2500    0      1     0       0       0       0
# 1            2  38.0  71.2833    1      1     0       0       0       0
# 2            3  26.0   7.9250    1      0     0       0       0       0
# 3            4  35.0  53.1000    1      1     0       0       0       0
# 4            5  35.0   8.0500    0      0     0       0       0       0
#
#    zero.4  ...  zero.12  zero.13  zero.14  Pclass  zero.15  zero.16  Embarked  \
# ...
