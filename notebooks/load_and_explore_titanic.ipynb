# %%
from titanic_surv.dataset import load_data

# Load dataset
data = load_data()

# Preview first 5 rows
data.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 4
#       1 from titanic_surv.dataset import load_data
#       3 # Load dataset
# ----> 4 data = load_data()
#       6 # Preview first 5 rows
#       7 data.head()
#
# TypeError: load_data() missing 1 required positional argument: 'input_path'
